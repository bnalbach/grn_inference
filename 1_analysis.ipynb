# %% [markdown]
# # Initial Data Analysis

# %%
import pandas as pd
import scanpy as sc

# %%
basedir = "/home/data/single_cell"

path_TMS_10x = f"{basedir}/tabular_muris_senis/TMS_bone_marrow_10x.h5ad"
path_TMS_smart_seq2 = f"{basedir}/tabular_muris_senis/TMS_bone_marrow_smart-seq2.h5ad"

path_GSE120221 = f"{basedir}/GSE120221/"

# %% [markdown]
# ### Tabular Muris Senis

# %%
TMS_10x_adata = sc.read_h5ad(path_TMS_10x)

print(TMS_10x_adata.var)
print(TMS_10x_adata.obs)
print(TMS_10x_adata.X)
# Out:
#                     n_cells     means  dispersions  dispersions_norm  \
# ENSMUSG00000029422   146507  0.534144     0.508502         -0.457014
# ENSMUSG00000049036     3148  0.009204     0.569458          0.320760
# ENSMUSG00000029577    33746  0.089575     0.418548         -0.003521
# ENSMUSG00000040746    86849  0.397830     0.631731         -0.200238
# ENSMUSG00000020590    23990  0.069944     0.446899          0.057401
# ...                     ...       ...          ...               ...
# ENSMUSG00000020070    10132  0.011803     0.497326          0.165759
# ENSMUSG00000030178       71  0.000315     0.592876          0.371080
# ENSMUSG00000021033    37219  0.049368     0.065278         -0.762637
# ENSMUSG00000030657     4032  0.013605     0.517908          0.209986
# ENSMUSG00000040693     1691  0.034971     0.437621          0.037463
#
#                     highly_variable  feature_is_filtered feature_name  \
# ...

# %%
sc.pl.umap(TMS_10x_adata)

# %%
TMS_smart_seq2_adata = sc.read_h5ad(path_TMS_smart_seq2)

print(TMS_smart_seq2_adata.var)
print(TMS_smart_seq2_adata.obs)
print(TMS_smart_seq2_adata.X)
# Out:
#                     n_cells         means  dispersions  dispersions_norm  \
# ENSMUSG00000029422    65053  6.280122e-01     1.626888         -0.373029
# ENSMUSG00000076126       20  1.000000e-12          NaN               NaN
# ENSMUSG00000049036     3000  5.051547e-02     0.761174         -0.164888
# ENSMUSG00000029577    22639  2.273459e-01     1.881215          0.515227
# ENSMUSG00000040746    52908  9.602000e-01     2.140848          0.269865
# ...                     ...           ...          ...               ...
# ENSMUSG00000102368      121  1.425653e-04     0.661081         -0.225666
# ENSMUSG00000021033    21213  1.927526e-01     1.313123          0.170268
# ENSMUSG00000073940     6988  8.785301e-01     6.163292          7.398061
# ENSMUSG00000037924       68  6.078320e-03     4.347728          2.012949
# ENSMUSG00000040693     1004  4.573243e-02     1.359823          0.198626
#
#                     highly_variable  feature_is_filtered   feature_name  \
# ...

# %% [markdown]
# ### GSE120221
