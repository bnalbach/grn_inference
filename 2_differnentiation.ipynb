# %% [markdown]
# # Dynamics of Mouse Bone Marrow Differentiation

# %% [markdown]
# [Introduction to PySINDy](https://www.youtube.com/watch?v=DvbbXX8Bd90)

# %% [markdown]
# Inferring Pseudotime

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ## SINDy Implementation

# %% [markdown]
# ## Applying SINDy
